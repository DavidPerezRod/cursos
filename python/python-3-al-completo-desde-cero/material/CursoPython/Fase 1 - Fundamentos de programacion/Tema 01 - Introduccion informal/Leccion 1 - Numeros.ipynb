# %%
3+2
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
#División
3/2
# Out:
# 1.5

# %%
#Módulo
3%2
# Out:
# 1

# %%
#Potencia
3**2
# Out:
# 9

# %%
3-2+4*10
# Out:
# 41

# %%
#En python no hace falta definir el tipo de las variables. Se infiere
n=3
n
# Out:
# 3

# %%
n +3
# Out:
# 6

# %%
n*2
# Out:
# 6

# %%
n*n
# Out:
# 9

# %%
n**n
# Out:
# 27

# %%
n**2
# Out:
# 9

# %% [markdown]
# m=10

# %%
m=10

# %%
n+m+10
# Out:
# 23

# %%
n=10
m=15
n+m
# Out:
# 25

# %%
n=m

# %%
n
# Out:
# 15

# %%
nota1= 5
nota2=10
notaMedia= (nota1 + nota2)/2
notaMedia
# Out:
# 7.5

# %%
nota1= 7.5
nota2=10
notaMedia= (nota1 + nota2)/2
notaMedia
# Out:
# 8.75
